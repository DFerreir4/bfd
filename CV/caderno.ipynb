# %%
#016
import math

numero = float(input("Digite um número real : "))

print(f"O número digitado foi {numero}. Tem a parte inteira {math.trunc(numero)}")
# Out:
# O número digitado foi 6.124. Tem a parte inteira 6

# %%
#017
