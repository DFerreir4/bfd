# %%
#1

def dobrar(numero):
    dobro = numero*2
    return dobro

dobrar(5)
# Out:
# 10

# %%
#2

class Livro:

    def __init__(self,titulo,autor):
        self.titulo = titulo
        self.autor = autor

    def exibir_dados(self):
        print(f"Titulo : [{self.titulo}]\n Autor : [{self.autor}]")

l = Livro("1984","George Orwell")
l.exibir_dados()
# Out:
# Titulo : [1984]
#  Autor : [George Orwell]

# %%
#3

class Carro:

    def __init__(self,modelo,cor):
        self.modelo = modelo
        self.cor = cor

meu_carro = Carro("Fusca","Azul")
meu_carro.cor = "Vermelho"

print(f"Modelo do carro : [{meu_carro.modelo}]\n Cor do carro : [{meu_carro.cor}]")
# Out:
# Modelo do carro : [Fusca]
#  Cor do carro : [Vermelho]

# %%
#4

def calcular_imc(peso,altura):
    
    imc = peso/(altura**2)

    if imc < 18.5:
        return f"Abaixo do Peso! Seu IMC foi : {imc:,.2f}"
    elif imc >= 18.5 or imc < 24.9:
        return f"Peso Normal! Seu IMC foi : {imc:,.2f}"
    elif imc == 25 or imc <= 29.9:
        return f"Sobrepeso! Seu IMC foi : {imc:,.2f}"
    elif imc >= 30:
        return f"Obesidade! Seu IMC foi : {imc:,.2f}"
    

calcular_imc(70,1.75)
# Out:
# 'Peso Normal! Seu IMC foi : 22.86'

# %%
#5

class Conta:

    def __init__(self,saldo=0):
        self.saldo = saldo

    def depositar(self,valor):
        self.saldo += valor
        return f"Foi depositado o valor de R$ {valor:.2f}"

    def sacar(self,valor):
        if valor > 0:
            if valor <= self.saldo:
                self.saldo -= valor
                return f"Você sacou R$ {valor:.2f}. Seu saldo é R$ {self.saldo}"
            else:
                return f"Sua conta está com o saldo R$ {self.saldo:.2f}. Não é possivel sacar o valor R$ {valor:.2f}."

c = Conta()
print("-"*30)
print(f"Saldo Inicial: {c.saldo}")
print("-"*30)
c.depositar(100)
print(f"+ Credito : {c.saldo}")
c.sacar(30)
print(f"- Debito : {c.sacar(self.saldo)}")
print("-"*30)
print(f"Saldo Total: {c.saldo}")
print("-"*30)
# Out:
# ------------------------------
# Saldo Inicial: 0
# ------------------------------
# + Credito : 100
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 27
#      25 print(f"+ Credito : {c.saldo}")
#      26 c.sacar(30)
# ---> 27 print(f"- Debito : {c.valor}")
#      28 print("-"*30)
#      29 print(f"Saldo Total: {c.saldo}")
#
# AttributeError: 'Conta' object has no attribute 'valor'
